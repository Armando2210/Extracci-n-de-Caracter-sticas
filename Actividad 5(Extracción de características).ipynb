# %%
#Importamos las libreias pandas, numpy y matplolib respectivamente 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#carga desde un archivo .csv sin indice 
Micro_Retailer = pd.read_csv('Datos_Limpios_pais.csv')
Micro_Retailer.head(5)
# Out:
#    Unnamed: 0        id                          listing_url  host_since  \
# 0           0   97945.0   https://www.airbnb.com/rooms/97945  18/04/2011
# 1           1  114695.0  https://www.airbnb.com/rooms/114695  12/05/2011
# 2           2  127383.0  https://www.airbnb.com/rooms/127383  26/05/2011
# 3           3  159634.0  https://www.airbnb.com/rooms/159634  01/07/2011
# 4           4  170154.0  https://www.airbnb.com/rooms/170154  14/04/2010
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                   6%
# 1      within an hour               100%                  99%
# 2      within an hour               100%                  92%
# 3      within an hour               100%                  78%
# 4  within a few hours               100%                 100%
#
#   host_is_superhost                host_verifications neighbourhood_cleansed  \
# ...

# %%
Micro_Retailer_2 = Micro_Retailer.drop(['Unnamed: 0'], axis=1)

# %%
#carga desde un archivo .csv sin indice 
Micro_Retailer_2
# Out:
#                 id                                       listing_url  \
# 0     9.794500e+04                https://www.airbnb.com/rooms/97945
# 1     1.146950e+05               https://www.airbnb.com/rooms/114695
# 2     1.273830e+05               https://www.airbnb.com/rooms/127383
# 3     1.596340e+05               https://www.airbnb.com/rooms/159634
# 4     1.701540e+05               https://www.airbnb.com/rooms/170154
# ...            ...                                               ...
# 8016  1.252200e+18  https://www.airbnb.com/rooms/1252204445878776998
# 8017  1.252220e+18  https://www.airbnb.com/rooms/1252221965097369365
# 8018  1.252240e+18  https://www.airbnb.com/rooms/1252243902096578406
# 8019  1.252300e+18  https://www.airbnb.com/rooms/1252302783564354993
# 8020  1.252330e+18  https://www.airbnb.com/rooms/1252332854831287401
#
#       host_since            host_response_time host_response_rate  \
# 0     18/04/2011            a few days or more                 0%
# ...

# %%
#Verificamos información del DataFrame
Micro_Retailer_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8021 entries, 0 to 8020
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            8021 non-null   float64
#  1   listing_url                                   8021 non-null   object
#  2   host_since                                    8021 non-null   object
#  3   host_response_time                            8021 non-null   object
#  4   host_response_rate                            8021 non-null   object
#  5   host_acceptance_rate                          8021 non-null   object
#  6   host_is_superhost                             8021 non-null   object
#  7   host_verifications                            8021 non-null   object
#  8   neighbourhood_cleansed                        8021 non-null   object
# ...

# %%
#Imprimo los primeros cinco registros del DataFrame
Micro_Retailer_2.head(5)
# Out:
#          id                          listing_url  host_since  \
# 0   97945.0   https://www.airbnb.com/rooms/97945  18/04/2011
# 1  114695.0  https://www.airbnb.com/rooms/114695  12/05/2011
# 2  127383.0  https://www.airbnb.com/rooms/127383  26/05/2011
# 3  159634.0  https://www.airbnb.com/rooms/159634  01/07/2011
# 4  170154.0  https://www.airbnb.com/rooms/170154  14/04/2010
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                   6%
# 1      within an hour               100%                  99%
# 2      within an hour               100%                  92%
# 3      within an hour               100%                  78%
# 4  within a few hours               100%                 100%
#
#   host_is_superhost                host_verifications neighbourhood_cleansed  \
# 0                 f                ['email', 'phone']                 Hadern
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer_2)
# Out:
#                                            listing_url  frequency  percentage  \
# 0                   https://www.airbnb.com/rooms/97945          1    0.000125
# 1      https://www.airbnb.com/rooms/981960706096511114          1    0.000125
# 2      https://www.airbnb.com/rooms/983040705145964653          1    0.000125
# 3      https://www.airbnb.com/rooms/983019993984355592          1    0.000125
# 4      https://www.airbnb.com/rooms/982990706851616291          1    0.000125
# ...                                                ...        ...         ...
# 8016             https://www.airbnb.com/rooms/50344164          1    0.000125
# 8017             https://www.airbnb.com/rooms/50335544          1    0.000125
# 8018             https://www.airbnb.com/rooms/50318161          1    0.000125
# 8019             https://www.airbnb.com/rooms/50317859          1    0.000125
# 8020  https://www.airbnb.com/rooms/1252332854831287401          1    0.000125
#
#       cumulative_perc
# ...

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table1 = freq_tbl(Micro_Retailer_2['host_is_superhost'])
table1
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       6749    0.841416         0.841416
# 1                 t       1203    0.149981         0.991398
# 2   Sin identificar         69    0.008602         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table2 = table1.drop(['percentage', 'cumulative_perc'], axis=1)
table2
# Out:
#   host_is_superhost  frequency
# 0                 f       6749
# 1                 t       1203
# 2   Sin identificar         69

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
# filtro = table2[table2['host_is_superhost']]
# filtro
#Filtro 3, FECHA_ENT (Fechas de "28/02/2022")
# filtro = table2[(table2["host_is_superhost"] == "t") & (table2["host_is_superhost"] == "f")]
filtro = table2[(table2["frequency"] > 500)]
filtro
# Out:
#   host_is_superhost  frequency
# 0                 f       6749
# 1                 t       1203

# %%
#Ajusto el indice de mi DataFrame
Filtro_index = filtro.set_index('host_is_superhost')
Filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                       6749
# t                       1203

# %%
#Realizamos grafico de barras del Dataframe filtrado
Filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Super host')
plt.xlabel('Tipo de super_host')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table3 = freq_tbl(Micro_Retailer_2['host_response_time'])
table3
# Out:
#              host_response_time  frequency  percentage  cumulative_perc
# 0                within an hour       2743    0.341977         0.341977
# 1  Estado de manera desconocida       2168    0.270290         0.612268
# 2            within a few hours       1420    0.177035         0.789303
# 3                  within a day       1098    0.136891         0.926194
# 4            a few days or more        592    0.073806         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table4 = table3.drop(['percentage', 'cumulative_perc'], axis=1)
table4
# Out:
#              host_response_time  frequency
# 0                within an hour       2743
# 1  Estado de manera desconocida       2168
# 2            within a few hours       1420
# 3                  within a day       1098
# 4            a few days or more        592

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro2 = table4[table4['frequency'] != 592]
filtro2
# Out:
#              host_response_time  frequency
# 0                within an hour       2743
# 1  Estado de manera desconocida       2168
# 2            within a few hours       1420
# 3                  within a day       1098

# %%
#Ajusto el indice de mi DataFrame
Filtro_index1 = filtro2.set_index('host_response_time')
Filtro_index1
# Out:
#                               frequency
# host_response_time
# within an hour                     2743
# Estado de manera desconocida       2168
# within a few hours                 1420
# within a day                       1098

# %%
#Realizamos grafico de barras del Dataframe filtrado
Filtro_index1.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "blue")
plt.title('Tiempo de respuesta a los usuarios')
plt.xlabel('Tiempo de respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index1.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='host_response_time'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table5 = freq_tbl(Micro_Retailer_2['host_verifications'])
table5
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       6274    0.782197         0.782197
# 1                         ['phone']        898    0.111956         0.894153
# 2  ['email', 'phone', 'work_email']        823    0.102606         0.996759
# 3           ['phone', 'work_email']         18    0.002244         0.999003
# 4                         ['email']          7    0.000873         0.999875
# 5                                []          1    0.000125         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table6 = table5.drop(['percentage', 'cumulative_perc'], axis=1)
table6
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       6274
# 1                         ['phone']        898
# 2  ['email', 'phone', 'work_email']        823
# 3           ['phone', 'work_email']         18
# 4                         ['email']          7
# 5                                []          1

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro3 = table6[table6['frequency'] > 600]
filtro3
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       6274
# 1                         ['phone']        898
# 2  ['email', 'phone', 'work_email']        823

# %%
#Ajusto el indice de mi DataFrame
Filtro_index2 = filtro3.set_index('host_verifications')
Filtro_index2
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                     6274
# ['phone']                               898
# ['email', 'phone', 'work_email']        823

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index2["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table7 = freq_tbl(Micro_Retailer_2['host_since'])
table7
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     25/11/2020         79    0.009849         0.009849
# 1     29/07/2018         35    0.004364         0.014213
# 2     30/08/2011         32    0.003990         0.018202
# 3     17/12/2015         27    0.003366         0.021568
# 4     07/04/2021         25    0.003117         0.024685
# ...          ...        ...         ...              ...
# 3213  13/11/2019          1    0.000125         0.999501
# 3214  07/09/2019          1    0.000125         0.999626
# 3215  14/06/2021          1    0.000125         0.999751
# 3216  23/09/2021          1    0.000125         0.999875
# 3217  05/07/2013          1    0.000125         1.000000
#
# [3218 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table8 = table7.drop(['percentage', 'cumulative_perc'], axis=1)
table8
# Out:
#       host_since  frequency
# 0     25/11/2020         79
# 1     29/07/2018         35
# 2     30/08/2011         32
# 3     17/12/2015         27
# 4     07/04/2021         25
# ...          ...        ...
# 3213  13/11/2019          1
# 3214  07/09/2019          1
# 3215  14/06/2021          1
# 3216  23/09/2021          1
# 3217  05/07/2013          1
#
# [3218 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro4 = table8[table8['frequency'] > 10]
filtro4
# Out:
#     host_since  frequency
# 0   25/11/2020         79
# 1   29/07/2018         35
# 2   30/08/2011         32
# 3   17/12/2015         27
# 4   07/04/2021         25
# 5   27/02/2018         19
# 6   03/05/2023         18
# 7   23/10/2020         18
# 8   12/05/2016         17
# 9   02/08/2013         16
# 10  26/12/2017         15
# 11  03/09/2019         15
# 12  08/11/2019         15
# 13  18/08/2014         15
# 14  24/08/2016         14
# 15  30/08/2016         14
# 16  01/02/2020         14
# 17  12/12/2022         13
# 18  04/12/2023         13
# 19  10/08/2015         12
# 20  24/05/2022         11
# 21  25/02/2022         11
# 22  23/03/2018         11
# 23  30/11/2021         11
# 24  29/08/2014         11
# 25  22/03/2022         11
# 26  27/06/2022         11
# 27  15/05/2017         11

# %%
#Ajusto el indice de mi DataFrame
Filtro_index3 = filtro4.set_index('host_since')
Filtro_index3
# Out:
#             frequency
# host_since
# 25/11/2020         79
# 29/07/2018         35
# 30/08/2011         32
# 17/12/2015         27
# 07/04/2021         25
# 27/02/2018         19
# 03/05/2023         18
# 23/10/2020         18
# 12/05/2016         17
# 02/08/2013         16
# 26/12/2017         15
# 03/09/2019         15
# 08/11/2019         15
# 18/08/2014         15
# 24/08/2016         14
# 30/08/2016         14
# 01/02/2020         14
# 12/12/2022         13
# 04/12/2023         13
# 10/08/2015         12
# 24/05/2022         11
# 25/02/2022         11
# 23/03/2018         11
# 30/11/2021         11
# 29/08/2014         11
# 22/03/2022         11
# 27/06/2022         11
# 15/05/2017         11

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table7.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table9 = freq_tbl(Micro_Retailer_2['neighbourhood_cleansed'])
table9
# Out:
#                                neighbourhood_cleansed  frequency  percentage  \
# 0                        Ludwigsvorstadt-Isarvorstadt       1004    0.125171
# 1                                         Maxvorstadt        641    0.079915
# 2                                       Au-Haidhausen        537    0.066949
# 3                                      Schwabing-West        500    0.062336
# 4                               Neuhausen-Nymphenburg        460    0.057349
# 5                                  Schwabing-Freimann        385    0.047999
# 6                                         Bogenhausen        359    0.044758
# 7                                  Ramersdorf-Perlach        351    0.043760
# 8                                            Sendling        304    0.037901
# 9                               Milbertshofen-Am Hart        299    0.037277
# 10                                  Sendling-Westpark        295    0.036778
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table10 = table9.drop(['percentage', 'cumulative_perc'], axis=1)
table10
# Out:
#                                neighbourhood_cleansed  frequency
# 0                        Ludwigsvorstadt-Isarvorstadt       1004
# 1                                         Maxvorstadt        641
# 2                                       Au-Haidhausen        537
# 3                                      Schwabing-West        500
# 4                               Neuhausen-Nymphenburg        460
# 5                                  Schwabing-Freimann        385
# 6                                         Bogenhausen        359
# 7                                  Ramersdorf-Perlach        351
# 8                                            Sendling        304
# 9                               Milbertshofen-Am Hart        299
# 10                                  Sendling-Westpark        295
# 11  Thalkirchen-Obersendling-Forstenried-Fürstenri...        287
# 12                                   Schwanthalerhöhe        283
# ...

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro5 = table10[table10['frequency'] > 250]
filtro5
# Out:
#                                neighbourhood_cleansed  frequency
# 0                        Ludwigsvorstadt-Isarvorstadt       1004
# 1                                         Maxvorstadt        641
# 2                                       Au-Haidhausen        537
# 3                                      Schwabing-West        500
# 4                               Neuhausen-Nymphenburg        460
# 5                                  Schwabing-Freimann        385
# 6                                         Bogenhausen        359
# 7                                  Ramersdorf-Perlach        351
# 8                                            Sendling        304
# 9                               Milbertshofen-Am Hart        299
# 10                                  Sendling-Westpark        295
# 11  Thalkirchen-Obersendling-Forstenried-Fürstenri...        287
# 12                                   Schwanthalerhöhe        283
# ...

# %%
#Ajusto el indice de mi DataFrame
Filtro_index4 = filtro5.set_index('neighbourhood_cleansed')
Filtro_index4
# Out:
#                                                     frequency
# neighbourhood_cleansed
# Ludwigsvorstadt-Isarvorstadt                             1004
# Maxvorstadt                                               641
# Au-Haidhausen                                             537
# Schwabing-West                                            500
# Neuhausen-Nymphenburg                                     460
# Schwabing-Freimann                                        385
# Bogenhausen                                               359
# Ramersdorf-Perlach                                        351
# Sendling                                                  304
# Milbertshofen-Am Hart                                     299
# Sendling-Westpark                                         295
# Thalkirchen-Obersendling-Forstenried-Fürstenrie...        287
# Schwanthalerhöhe                                          283
# Obergiesing                                               276
# ...

# %%
#Realizamos grafico hexadecimal del dataframe filtrado, alternativo a scatter plot
table9.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table11 = freq_tbl(Micro_Retailer_2['room_type'])
table11
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       5331    0.664630         0.664630
# 1     Private room       2599    0.324024         0.988655
# 2      Shared room         59    0.007356         0.996010
# 3       Hotel room         32    0.003990         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table12 = table11.drop(['percentage', 'cumulative_perc'], axis=1)
table12
# Out:
#          room_type  frequency
# 0  Entire home/apt       5331
# 1     Private room       2599
# 2      Shared room         59
# 3       Hotel room         32

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro6 = table12[table12['frequency'] > 30]
filtro6
# Out:
#          room_type  frequency
# 0  Entire home/apt       5331
# 1     Private room       2599
# 2      Shared room         59
# 3       Hotel room         32

# %%
#Ajusto el indice de mi DataFrame
Filtro_index5 = filtro6.set_index('room_type')
Filtro_index5
# Out:
#                  frequency
# room_type
# Entire home/apt       5331
# Private room          2599
# Shared room             59
# Hotel room              32

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index5.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='room_type'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table13 = freq_tbl(Micro_Retailer_2['property_type'])
table13
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       4423    0.551428         0.551428
# 1          Private room in rental unit       1761    0.219549         0.770976
# 2                         Entire condo        418    0.052113         0.823089
# 3                 Private room in home        277    0.034534         0.857624
# 4            Entire serviced apartment        213    0.026555         0.884179
# 5                Private room in condo        175    0.021818         0.905997
# 6                        Room in hotel        135    0.016831         0.922828
# 7                          Entire home         95    0.011844         0.934671
# 8                          Entire loft         80    0.009974         0.944645
# 9               Room in boutique hotel         73    0.009101         0.953746
# 10           Private room in townhouse         60    0.007480         0.961227
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table14 = table13.drop(['percentage', 'cumulative_perc'], axis=1)
table14
# Out:
#                          property_type  frequency
# 0                   Entire rental unit       4423
# 1          Private room in rental unit       1761
# 2                         Entire condo        418
# 3                 Private room in home        277
# 4            Entire serviced apartment        213
# 5                Private room in condo        175
# 6                        Room in hotel        135
# 7                          Entire home         95
# 8                          Entire loft         80
# 9               Room in boutique hotel         73
# 10           Private room in townhouse         60
# 11          Shared room in rental unit         39
# 12                  Room in aparthotel         33
# 13   Private room in bed and breakfast         27
# 14                    Entire townhouse         26
# 15              Private room in hostel         23
# 16  Private room in serviced apartment         17
# 17          Private room in guesthouse         14
# ...

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro7 = table14[table14['frequency'] > 100]
filtro7
# Out:
#                  property_type  frequency
# 0           Entire rental unit       4423
# 1  Private room in rental unit       1761
# 2                 Entire condo        418
# 3         Private room in home        277
# 4    Entire serviced apartment        213
# 5        Private room in condo        175
# 6                Room in hotel        135

# %%
#Ajusto el indice de mi DataFrame
Filtro_index6 = filtro7.set_index('property_type')
Filtro_index6
# Out:
#                              frequency
# property_type
# Entire rental unit                4423
# Private room in rental unit       1761
# Entire condo                       418
# Private room in home               277
# Entire serviced apartment          213
# Private room in condo              175
# Room in hotel                      135

# %%
#Realizamos grafico de pastel de dataframe filtrado 
Filtro_index6["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('property_type')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table15 = freq_tbl(Micro_Retailer_2['has_availability'])
table15
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       8014    0.999127         0.999127
# 1                f          7    0.000873         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table16 = table15.drop(['percentage', 'cumulative_perc'], axis=1)
table16
# Out:
#   has_availability  frequency
# 0                t       8014
# 1                f          7

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro8 = table16[table16['frequency'] > 5]
filtro8
# Out:
#   has_availability  frequency
# 0                t       8014
# 1                f          7

# %%
#Ajusto el indice de mi DataFrame
Filtro_index7 = filtro8.set_index('has_availability')
Filtro_index7
# Out:
#                   frequency
# has_availability
# t                      8014
# f                         7

# %%
#Realizamos grafico de barras del Dataframe filtrado
Filtro_index7.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('has availability')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table17 = freq_tbl(Micro_Retailer_2['amenities'])
table17
# Out:
#                                               amenities  frequency  \
# 0     ["Smoke alarm", "TV", "Washer", "Kitchen", "Wi...         32
# 1     ["Smoke alarm", "Dedicated workspace", "TV", "...         29
# 2     ["Smoke alarm", "Dedicated workspace", "Washer...         28
# 3          ["Smoke alarm", "Wifi", "Kitchen", "Washer"]         25
# 4                   ["Wifi", "TV", "Kitchen", "Washer"]         23
# ...                                                 ...        ...
# 7310  ["Shared backyard", "Hot water kettle", "Free ...          1
# 7311  ["Heating", "Coffee maker", "Stove", "Bed line...          1
# 7312  ["Luggage dropoff allowed", "Heating", "Hot wa...          1
# 7313  ["Smoke alarm", "Dedicated workspace", "Hanger...          1
# 7314  ["Heating", "Hot water kettle", "Coffee maker:...          1
#
#       percentage  cumulative_perc
# 0       0.003990         0.003990
# 1       0.003616         0.007605
# 2       0.003491         0.011096
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table18 = table17.drop(['percentage', 'cumulative_perc'], axis=1)
table18
# Out:
#                                               amenities  frequency
# 0     ["Smoke alarm", "TV", "Washer", "Kitchen", "Wi...         32
# 1     ["Smoke alarm", "Dedicated workspace", "TV", "...         29
# 2     ["Smoke alarm", "Dedicated workspace", "Washer...         28
# 3          ["Smoke alarm", "Wifi", "Kitchen", "Washer"]         25
# 4                   ["Wifi", "TV", "Kitchen", "Washer"]         23
# ...                                                 ...        ...
# 7310  ["Shared backyard", "Hot water kettle", "Free ...          1
# 7311  ["Heating", "Coffee maker", "Stove", "Bed line...          1
# 7312  ["Luggage dropoff allowed", "Heating", "Hot wa...          1
# 7313  ["Smoke alarm", "Dedicated workspace", "Hanger...          1
# 7314  ["Heating", "Hot water kettle", "Coffee maker:...          1
#
# [7315 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro9 = table18[table18['frequency'] > 9]
filtro9
# Out:
#                                             amenities  frequency
# 0   ["Smoke alarm", "TV", "Washer", "Kitchen", "Wi...         32
# 1   ["Smoke alarm", "Dedicated workspace", "TV", "...         29
# 2   ["Smoke alarm", "Dedicated workspace", "Washer...         28
# 3        ["Smoke alarm", "Wifi", "Kitchen", "Washer"]         25
# 4                 ["Wifi", "TV", "Kitchen", "Washer"]         23
# 5                                                  []         18
# 6   ["Smoke alarm", "TV", "Washer", "Free parking ...         14
# 7   ["Smoke alarm", "Fire extinguisher", "Dedicate...         14
# 8   ["Smoke alarm", "Dedicated workspace", "Washer...         13
# 9                       ["Wifi", "Kitchen", "Washer"]         12
# 10  ["Smoke alarm", "Dedicated workspace", "Paid p...         12
# 11           ["Smoke alarm", "TV", "Kitchen", "Wifi"]         11
# 12  ["Dryer", "Dishes and silverware", "Dedicated ...         11
# ...

# %%
#Ajusto el indice de mi DataFrame
Filtro_index8 = filtro9.set_index('amenities')
Filtro_index8
# Out:
#                                                     frequency
# amenities
# ["Smoke alarm", "TV", "Washer", "Kitchen", "Wifi"]         32
# ["Smoke alarm", "Dedicated workspace", "TV", "W...         29
# ["Smoke alarm", "Dedicated workspace", "Washer"...         28
# ["Smoke alarm", "Wifi", "Kitchen", "Washer"]               25
# ["Wifi", "TV", "Kitchen", "Washer"]                        23
# []                                                         18
# ["Smoke alarm", "TV", "Washer", "Free parking o...         14
# ["Smoke alarm", "Fire extinguisher", "Dedicated...         14
# ["Smoke alarm", "Dedicated workspace", "Washer"...         13
# ["Wifi", "Kitchen", "Washer"]                              12
# ["Smoke alarm", "Dedicated workspace", "Paid pa...         12
# ["Smoke alarm", "TV", "Kitchen", "Wifi"]                   11
# ["Dryer", "Dishes and silverware", "Dedicated w...         11
# ["Smoke alarm", "Dedicated workspace", "TV", "W...         10
# ...

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table17.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table19 = freq_tbl(Micro_Retailer_2['last_review'])
table19
# Out:
#      last_review  frequency  percentage  cumulative_perc
# 0     2024-12-05       2071    0.258197         0.258197
# 1     01/09/2024        333    0.041516         0.299713
# 2     22/09/2024        301    0.037526         0.337240
# 3     23/09/2024        232    0.028924         0.366164
# 4     25/08/2024        171    0.021319         0.387483
# ...          ...        ...         ...              ...
# 1057  22/06/2023          1    0.000125         0.999501
# 1058  02/03/2020          1    0.000125         0.999626
# 1059  13/06/2021          1    0.000125         0.999751
# 1060  28/10/2021          1    0.000125         0.999875
# 1061  19/05/2024          1    0.000125         1.000000
#
# [1062 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table20 = table19.drop(['percentage', 'cumulative_perc'], axis=1)
table20
# Out:
#      last_review  frequency
# 0     2024-12-05       2071
# 1     01/09/2024        333
# 2     22/09/2024        301
# 3     23/09/2024        232
# 4     25/08/2024        171
# ...          ...        ...
# 1057  22/06/2023          1
# 1058  02/03/2020          1
# 1059  13/06/2021          1
# 1060  28/10/2021          1
# 1061  19/05/2024          1
#
# [1062 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro10 = table20[table20['frequency'] > 100]
filtro10
# Out:
#   last_review  frequency
# 0  2024-12-05       2071
# 1  01/09/2024        333
# 2  22/09/2024        301
# 3  23/09/2024        232
# 4  25/08/2024        171
# 5  18/08/2024        130
# 6  24/09/2024        117
# 7  02/09/2024        116
# 8  31/08/2024        108
# 9  01/10/2023        106

# %%
#Ajusto el indice de mi DataFrame
Filtro_index9 = filtro10.set_index('last_review')
Filtro_index9
# Out:
#              frequency
# last_review
# 2024-12-05        2071
# 01/09/2024         333
# 22/09/2024         301
# 23/09/2024         232
# 25/08/2024         171
# 18/08/2024         130
# 24/09/2024         117
# 02/09/2024         116
# 31/08/2024         108
# 01/10/2023         106

# %%
#Realizamos grafico de barras del Dataframe filtrado
Filtro_index9.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('última revsión')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table21 = freq_tbl(Micro_Retailer_2['first_review'])
table21
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0      2011-06-19       2071    0.258197         0.258197
# 1      24/09/2023         92    0.011470         0.269667
# 2      22/09/2024         71    0.008852         0.278519
# 3      17/09/2023         68    0.008478         0.286997
# 4      25/09/2022         63    0.007854         0.294851
# ...           ...        ...         ...              ...
# 2032   11/05/2017          1    0.000125         0.999501
# 2033   13/12/2020          1    0.000125         0.999626
# 2034   22/12/2020          1    0.000125         0.999751
# 2035   29/12/2020          1    0.000125         0.999875
# 2036   03/10/2011          1    0.000125         1.000000
#
# [2037 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table22 = table21.drop(['percentage', 'cumulative_perc'], axis=1)
table22
# Out:
#      first_review  frequency
# 0      2011-06-19       2071
# 1      24/09/2023         92
# 2      22/09/2024         71
# 3      17/09/2023         68
# 4      25/09/2022         63
# ...           ...        ...
# 2032   11/05/2017          1
# 2033   13/12/2020          1
# 2034   22/12/2020          1
# 2035   29/12/2020          1
# 2036   03/10/2011          1
#
# [2037 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro11 = table22[table22['frequency'] > 50]
filtro11
# Out:
#   first_review  frequency
# 0   2011-06-19       2071
# 1   24/09/2023         92
# 2   22/09/2024         71
# 3   17/09/2023         68
# 4   25/09/2022         63
# 5   21/06/2024         52

# %%
#Ajusto el indice de mi DataFrame
Filtro_index10 = filtro11.set_index('first_review')
Filtro_index10
# Out:
#               frequency
# first_review
# 2011-06-19         2071
# 24/09/2023           92
# 22/09/2024           71
# 17/09/2023           68
# 25/09/2022           63
# 21/06/2024           52

# %%
Filtro_index10.plot(kind='bar', width=0.8, figsize=(10,4), color='red')
plt.title('Primeras vistas')
plt.xlabel('Fechas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Obtengo un análisis univariado de una variable categórica en específico  
table23 = freq_tbl(Micro_Retailer_2['instant_bookable'])
table23
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       6645     0.82845          0.82845
# 1                t       1376     0.17155          1.00000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table24 = table23.drop(['percentage', 'cumulative_perc'], axis=1)
table24
# Out:
#   instant_bookable  frequency
# 0                f       6645
# 1                t       1376

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro12 = table24[table24['frequency'] > 1000]
filtro12
# Out:
#   instant_bookable  frequency
# 0                f       6645
# 1                t       1376

# %%
#Ajusto el indice de mi DataFrame
Filtro_index11 = filtro12.set_index('instant_bookable')
Filtro_index11
# Out:
#                   frequency
# instant_bookable
# f                      6645
# t                      1376

# %%
#Realizamos grafico de pastel de dataframe filtrado 
Filtro_index11["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('instant_bookable')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# #Obtengo un análisis univariado de una variable categórica en específico  
table25 = freq_tbl(Micro_Retailer_2['listing_url'])
table25
# Out:
#                                            listing_url  frequency  percentage  \
# 0                   https://www.airbnb.com/rooms/97945          1    0.000125
# 1      https://www.airbnb.com/rooms/981960706096511114          1    0.000125
# 2      https://www.airbnb.com/rooms/983040705145964653          1    0.000125
# 3      https://www.airbnb.com/rooms/983019993984355592          1    0.000125
# 4      https://www.airbnb.com/rooms/982990706851616291          1    0.000125
# ...                                                ...        ...         ...
# 8016             https://www.airbnb.com/rooms/50344164          1    0.000125
# 8017             https://www.airbnb.com/rooms/50335544          1    0.000125
# 8018             https://www.airbnb.com/rooms/50318161          1    0.000125
# 8019             https://www.airbnb.com/rooms/50317859          1    0.000125
# 8020  https://www.airbnb.com/rooms/1252332854831287401          1    0.000125
#
#       cumulative_perc
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table26 = table25.drop(['percentage', 'cumulative_perc'], axis=1)
table26
# Out:
#                                            listing_url  frequency
# 0                   https://www.airbnb.com/rooms/97945          1
# 1      https://www.airbnb.com/rooms/981960706096511114          1
# 2      https://www.airbnb.com/rooms/983040705145964653          1
# 3      https://www.airbnb.com/rooms/983019993984355592          1
# 4      https://www.airbnb.com/rooms/982990706851616291          1
# ...                                                ...        ...
# 8016             https://www.airbnb.com/rooms/50344164          1
# 8017             https://www.airbnb.com/rooms/50335544          1
# 8018             https://www.airbnb.com/rooms/50318161          1
# 8019             https://www.airbnb.com/rooms/50317859          1
# 8020  https://www.airbnb.com/rooms/1252332854831287401          1
#
# [8021 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro13 = table26[table26['frequency'] > 0]
filtro13
# Out:
#                                            listing_url  frequency
# 0                   https://www.airbnb.com/rooms/97945          1
# 1      https://www.airbnb.com/rooms/981960706096511114          1
# 2      https://www.airbnb.com/rooms/983040705145964653          1
# 3      https://www.airbnb.com/rooms/983019993984355592          1
# 4      https://www.airbnb.com/rooms/982990706851616291          1
# ...                                                ...        ...
# 8016             https://www.airbnb.com/rooms/50344164          1
# 8017             https://www.airbnb.com/rooms/50335544          1
# 8018             https://www.airbnb.com/rooms/50318161          1
# 8019             https://www.airbnb.com/rooms/50317859          1
# 8020  https://www.airbnb.com/rooms/1252332854831287401          1
#
# [8021 rows x 2 columns]

# %%
#Ajusto el indice de mi DataFrame
Filtro_index12 = filtro13.set_index('listing_url')
Filtro_index12
# Out:
#                                                   frequency
# listing_url
# https://www.airbnb.com/rooms/97945                        1
# https://www.airbnb.com/rooms/981960706096511114           1
# https://www.airbnb.com/rooms/983040705145964653           1
# https://www.airbnb.com/rooms/983019993984355592           1
# https://www.airbnb.com/rooms/982990706851616291           1
# ...                                                     ...
# https://www.airbnb.com/rooms/50344164                     1
# https://www.airbnb.com/rooms/50335544                     1
# https://www.airbnb.com/rooms/50318161                     1
# https://www.airbnb.com/rooms/50317859                     1
# https://www.airbnb.com/rooms/1252332854831287401          1
#
# [8021 rows x 1 columns]

# %%
table25.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
# Micro_Retailer_2['availability_30'] = Micro_Retailer_2['availability_30'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table27 = freq_tbl(Micro_Retailer_2['availability_30'])
table27
# Out:
#    availability_30  frequency  percentage  cumulative_perc
# 0                0       2787    0.347463         0.347463
# 1                1        336    0.041890         0.389353
# 2                2        317    0.039521         0.428874
# 3                3        265    0.033038         0.461912
# 4                4        263    0.032789         0.494701
# 5                5        227    0.028301         0.523002
# 6                6        210    0.026181         0.549183
# 7               23        185    0.023064         0.572248
# 8               19        178    0.022192         0.594440
# 9               20        176    0.021942         0.616382
# 10              21        173    0.021568         0.637950
# 11              30        173    0.021568         0.659519
# 12              17        170    0.021194         0.680713
# 13              22        168    0.020945         0.701658
# 14              18        166    0.020696         0.722354
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table28 = table27.drop(['percentage', 'cumulative_perc'], axis=1)
table28
# Out:
#    availability_30  frequency
# 0                0       2787
# 1                1        336
# 2                2        317
# 3                3        265
# 4                4        263
# 5                5        227
# 6                6        210
# 7               23        185
# 8               19        178
# 9               20        176
# 10              21        173
# 11              30        173
# 12              17        170
# 13              22        168
# 14              18        166
# 15               7        160
# 16               9        157
# 17               8        154
# 18              24        152
# 19              25        143
# 20              11        141
# 21              16        141
# 22              29        140
# 23              15        140
# 24              27        139
# 25              26        138
# 26              14        136
# 27              10        133
# 28              12        126
# 29              13        115
# ...

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro14 = table28[table28['frequency'] > 100]
filtro14
# Out:
#    availability_30  frequency
# 0                0       2787
# 1                1        336
# 2                2        317
# 3                3        265
# 4                4        263
# 5                5        227
# 6                6        210
# 7               23        185
# 8               19        178
# 9               20        176
# 10              21        173
# 11              30        173
# 12              17        170
# 13              22        168
# 14              18        166
# 15               7        160
# 16               9        157
# 17               8        154
# 18              24        152
# 19              25        143
# 20              11        141
# 21              16        141
# 22              29        140
# 23              15        140
# 24              27        139
# 25              26        138
# 26              14        136
# 27              10        133
# 28              12        126
# 29              13        115
# ...

# %%
#Ajusto el indice de mi DataFrame
Filtro_index13 = filtro14.set_index('availability_30')
Filtro_index13
# Out:
#                  frequency
# availability_30
# 0                     2787
# 1                      336
# 2                      317
# 3                      265
# 4                      263
# 5                      227
# 6                      210
# 23                     185
# 19                     178
# 20                     176
# 21                     173
# 30                     173
# 17                     170
# 22                     168
# 18                     166
# 7                      160
# 9                      157
# 8                      154
# 24                     152
# 25                     143
# 11                     141
# 16                     141
# 29                     140
# 15                     140
# 27                     139
# 26                     138
# 14                     136
# 10                     133
# 12                     126
# 13                     115
# 28                     112

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
table27.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
# Micro_Retailer_2['longitude'] = Micro_Retailer_2['longitude'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table29 = freq_tbl(Micro_Retailer_2['longitude'])
table29
# Out:
#       longitude  frequency  percentage  cumulative_perc
# 0     11.600000        637    0.079417         0.079417
# 1     11.560234         22    0.002743         0.082159
# 2     11.617343         18    0.002244         0.084403
# 3     11.617298         14    0.001745         0.086149
# 4     11.560280         12    0.001496         0.087645
# ...         ...        ...         ...              ...
# 6405  11.550859          1    0.000125         0.999501
# 6406  11.550840          1    0.000125         0.999626
# 6407  11.550819          1    0.000125         0.999751
# 6408  11.550800          1    0.000125         0.999875
# 6409  11.657270          1    0.000125         1.000000
#
# [6410 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table30 = table29.drop(['percentage', 'cumulative_perc'], axis=1)
table30
# Out:
#       longitude  frequency
# 0     11.600000        637
# 1     11.560234         22
# 2     11.617343         18
# 3     11.617298         14
# 4     11.560280         12
# ...         ...        ...
# 6405  11.550859          1
# 6406  11.550840          1
# 6407  11.550819          1
# 6408  11.550800          1
# 6409  11.657270          1
#
# [6410 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro15 = table30[table30['frequency'] > 8]
filtro15
# Out:
#    longitude  frequency
# 0  11.600000        637
# 1  11.560234         22
# 2  11.617343         18
# 3  11.617298         14
# 4  11.560280         12
# 5  11.527628         10

# %%
#Ajusto el indice de mi DataFrame
Filtro_index14 = filtro15.set_index('longitude')
Filtro_index14
# Out:
#            frequency
# longitude
# 11.600000        637
# 11.560234         22
# 11.617343         18
# 11.617298         14
# 11.560280         12
# 11.527628         10

# %%
#Realizamos grafico de barras del Dataframe filtrado
Filtro_index14.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "yellow")
plt.title('Longitud')
plt.xlabel('longitudes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Micro_Retailer_2['latitude'] = Micro_Retailer_2['latitude'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table31 = freq_tbl(Micro_Retailer_2['latitude'])
table31
# Out:
#        latitude  frequency  percentage  cumulative_perc
# 0     48.100000         85    0.010597         0.010597
# 1     48.139461         40    0.004987         0.015584
# 2     48.137646         22    0.002743         0.018327
# 3     48.111740         21    0.002618         0.020945
# 4     48.139463         16    0.001995         0.022940
# ...         ...        ...         ...              ...
# 6590  48.127823          1    0.000125         0.999501
# 6591  48.127819          1    0.000125         0.999626
# 6592  48.127810          1    0.000125         0.999751
# 6593  48.127801          1    0.000125         0.999875
# 6594  48.205970          1    0.000125         1.000000
#
# [6595 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table32 = table31.drop(['percentage', 'cumulative_perc'], axis=1)
table32
# Out:
#        latitude  frequency
# 0     48.100000         85
# 1     48.139461         40
# 2     48.137646         22
# 3     48.111740         21
# 4     48.139463         16
# ...         ...        ...
# 6590  48.127823          1
# 6591  48.127819          1
# 6592  48.127810          1
# 6593  48.127801          1
# 6594  48.205970          1
#
# [6595 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro16 = table32[table32['frequency'] > 8]
filtro16
# Out:
#     latitude  frequency
# 0  48.100000         85
# 1  48.139461         40
# 2  48.137646         22
# 3  48.111740         21
# 4  48.139463         16
# 5  48.111755         14
# 6  48.138500         13
# 7  48.097408         10

# %%
#Ajusto el indice de mi DataFrame
Filtro_index15 = filtro16.set_index('latitude')
Filtro_index15
# Out:
#            frequency
# latitude
# 48.100000         85
# 48.139461         40
# 48.137646         22
# 48.111740         21
# 48.139463         16
# 48.111755         14
# 48.138500         13
# 48.097408         10

# %%
Filtro_index15 #Realizamos grafico de barras del Dataframe filtrado
Filtro_index15.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Latitud')
plt.xlabel('latitud')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Micro_Retailer_2['minimum_nights'] = Micro_Retailer_2['minimum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table33 = freq_tbl(Micro_Retailer_2['minimum_nights'])
table33
# Out:
#   minimum_nights  frequency  percentage  cumulative_perc
# 0            1.0       2948    0.367535         0.367535
# 1            2.0       2054    0.256078         0.623613
# 2            3.0       1114    0.138885         0.762498
# 3            4.5       1080    0.134647         0.897145
# 4            5.0        370    0.046129         0.943274
# 5            4.0        334    0.041641         0.984915
# 6            6.0        121    0.015085         1.000000

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table34 = table33.drop(['percentage', 'cumulative_perc'], axis=1)
table34
# Out:
#   minimum_nights  frequency
# 0            1.0       2948
# 1            2.0       2054
# 2            3.0       1114
# 3            4.5       1080
# 4            5.0        370
# 5            4.0        334
# 6            6.0        121

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro17 = table34[table34['frequency'] > 8]
filtro17
# Out:
#   minimum_nights  frequency
# 0            1.0       2948
# 1            2.0       2054
# 2            3.0       1114
# 3            4.5       1080
# 4            5.0        370
# 5            4.0        334
# 6            6.0        121

# %%
#Ajusto el indice de mi DataFrame
Filtro_index16 = filtro17.set_index('minimum_nights')
Filtro_index16
# Out:
#                 frequency
# minimum_nights
# 1.0                  2948
# 2.0                  2054
# 3.0                  1114
# 4.5                  1080
# 5.0                   370
# 4.0                   334
# 6.0                   121

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index16["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
# Micro_Retailer_2['maximum_nights'] = Micro_Retailer_2['maximum_nights'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table35 = freq_tbl(Micro_Retailer_2['maximum_nights'])
table35
# Out:
#     maximum_nights  frequency  percentage  cumulative_perc
# 0            365.0       2602    0.324398         0.324398
# 1            334.1       1288    0.160578         0.484977
# 2             30.0        511    0.063708         0.548685
# 3             14.0        397    0.049495         0.598180
# 4              7.0        314    0.039147         0.637327
# ..             ...        ...         ...              ...
# 135          175.0          1    0.000125         0.999501
# 136          179.0          1    0.000125         0.999626
# 137          186.0          1    0.000125         0.999751
# 138          189.0          1    0.000125         0.999875
# 139          780.0          1    0.000125         1.000000
#
# [140 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table36 = table35.drop(['percentage', 'cumulative_perc'], axis=1)
table36
# Out:
#     maximum_nights  frequency
# 0            365.0       2602
# 1            334.1       1288
# 2             30.0        511
# 3             14.0        397
# 4              7.0        314
# ..             ...        ...
# 135          175.0          1
# 136          179.0          1
# 137          186.0          1
# 138          189.0          1
# 139          780.0          1
#
# [140 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro18 = table36[table36['frequency'] > 100]
filtro18
# Out:
#    maximum_nights  frequency
# 0           365.0       2602
# 1           334.1       1288
# 2            30.0        511
# 3            14.0        397
# 4             7.0        314
# 5           180.0        223
# 6            90.0        193
# 7            10.0        187
# 8            60.0        164
# 9            20.0        157
# 10            5.0        130
# 11           28.0        115
# 12           15.0        107
# 13          730.0        106
# 14           21.0        105
# 15           31.0        102

# %%
#Ajusto el indice de mi DataFrame
Filtro_index17 = filtro18.set_index('maximum_nights')
Filtro_index17
# Out:
#                 frequency
# maximum_nights
# 365.0                2602
# 334.1                1288
# 30.0                  511
# 14.0                  397
# 7.0                   314
# 180.0                 223
# 90.0                  193
# 10.0                  187
# 60.0                  164
# 20.0                  157
# 5.0                   130
# 28.0                  115
# 15.0                  107
# 730.0                 106
# 21.0                  105
# 31.0                  102

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index17.plot(kind='area', figsize=(10,4), alpha = 0.5)
# Out:
# <Axes: xlabel='maximum_nights'>

# %%
# Micro_Retailer_2['id'] = Micro_Retailer_2['id'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table37 = freq_tbl(Micro_Retailer_2['id'])
table37
# Out:
#                 id  frequency  percentage  cumulative_perc
# 0     1.014340e+18          6    0.000748         0.000748
# 1     1.248620e+18          5    0.000623         0.001371
# 2     1.244020e+18          5    0.000623         0.001995
# 3     8.889110e+17          5    0.000623         0.002618
# 4     1.246360e+18          5    0.000623         0.003241
# ...            ...        ...         ...              ...
# 7655  4.803873e+07          1    0.000125         0.999501
# 7656  4.803855e+07          1    0.000125         0.999626
# 7657  4.803849e+07          1    0.000125         0.999751
# 7658  4.790082e+07          1    0.000125         0.999875
# 7659  1.252330e+18          1    0.000125         1.000000
#
# [7660 rows x 4 columns]

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table38 = table37.drop(['percentage', 'cumulative_perc'], axis=1)
table38
# Out:
#                 id  frequency
# 0     1.014340e+18          6
# 1     1.248620e+18          5
# 2     1.244020e+18          5
# 3     8.889110e+17          5
# 4     1.246360e+18          5
# ...            ...        ...
# 7655  4.803873e+07          1
# 7656  4.803855e+07          1
# 7657  4.803849e+07          1
# 7658  4.790082e+07          1
# 7659  1.252330e+18          1
#
# [7660 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro19 = table38[table38['frequency'] > 3]
filtro19
# Out:
#              id  frequency
# 0  1.014340e+18          6
# 1  1.248620e+18          5
# 2  1.244020e+18          5
# 3  8.889110e+17          5
# 4  1.246360e+18          5
# 5  1.006490e+18          4
# 6  1.188850e+18          4
# 7  1.238900e+18          4
# 8  1.216520e+18          4

# %%
#Ajusto el indice de mi DataFrame
Filtro_index18 = filtro19.set_index('id')
Filtro_index18
# Out:
#               frequency
# id
# 1.014340e+18          6
# 1.248620e+18          5
# 1.244020e+18          5
# 8.889110e+17          5
# 1.246360e+18          5
# 1.006490e+18          4
# 1.188850e+18          4
# 1.238900e+18          4
# 1.216520e+18          4

# %%
 #Realizamos grafico de pastel de dataframe filtrado 
Filtro_index18["frequency"].plot(kind="pie", figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('host_id')
plt.xlabel('porcentaje')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# Micro_Retailer_2['review_scores_rating'] = Micro_Retailer_2['review_scores_rating'].astype('category')
#Obtengo un análisis univariado de una variable categórica en específico  
table39 = freq_tbl(Micro_Retailer_2['review_scores_rating'])
table39
# Out:
#    review_scores_rating  frequency  percentage  cumulative_perc
# 0                  5.00       2256    0.281262         0.281262
# 1                  4.90       2171    0.270665         0.551926
# 2                  4.80        778    0.096995         0.648922
# 3                  4.50        198    0.024685         0.673607
# 4                  4.67        187    0.023314         0.696921
# 5                  4.75        145    0.018078         0.714998
# 6                  4.83        130    0.016207         0.731206
# 7                  4.88        128    0.015958         0.747164
# 8                  4.86        118    0.014711         0.761875
# 9                  4.91        108    0.013465         0.775340
# 10                 4.89        106    0.013215         0.788555
# 11                 4.92        105    0.013091         0.801646
# 12                 4.93         94    0.011719         0.813365
# 13                 4.94         89    0.011096         0.824461
# ...

# %%
#Elimino las columnas "procentage" y "cumulative_perc" para trabajar con las fecuencias
table40 = table39.drop(['percentage', 'cumulative_perc'], axis=1)
table40
# Out:
#    review_scores_rating  frequency
# 0                  5.00       2256
# 1                  4.90       2171
# 2                  4.80        778
# 3                  4.50        198
# 4                  4.67        187
# 5                  4.75        145
# 6                  4.83        130
# 7                  4.88        128
# 8                  4.86        118
# 9                  4.91        108
# 10                 4.89        106
# 11                 4.92        105
# 12                 4.93         94
# 13                 4.94         89
# 14                 4.95         77
# 15                 4.96         74
# 16                 4.78         71
# 17                 4.85         69
# 18                 4.87         64
# 19                 4.71         63
# 20                 4.84         62
# 21                 4.82         59
# 22                 4.73         51
# 23                 4.60         49
# 24                 4.97         48
# 25                 4.79         48
# ...

# %%
#Obtengo un filtro de los valores más relevantes de las variables categóricas seleccionado
filtro20 = table40[table40['frequency'] > 60]
filtro20
# Out:
#    review_scores_rating  frequency
# 0                  5.00       2256
# 1                  4.90       2171
# 2                  4.80        778
# 3                  4.50        198
# 4                  4.67        187
# 5                  4.75        145
# 6                  4.83        130
# 7                  4.88        128
# 8                  4.86        118
# 9                  4.91        108
# 10                 4.89        106
# 11                 4.92        105
# 12                 4.93         94
# 13                 4.94         89
# 14                 4.95         77
# 15                 4.96         74
# 16                 4.78         71
# 17                 4.85         69
# 18                 4.87         64
# 19                 4.71         63
# 20                 4.84         62

# %%
#Ajusto el indice de mi DataFrame
Filtro_index19 = filtro20.set_index('review_scores_rating')
Filtro_index19
# Out:
#                       frequency
# review_scores_rating
# 5.00                       2256
# 4.90                       2171
# 4.80                        778
# 4.50                        198
# 4.67                        187
# 4.75                        145
# 4.83                        130
# 4.88                        128
# 4.86                        118
# 4.91                        108
# 4.89                        106
# 4.92                        105
# 4.93                         94
# 4.94                         89
# 4.95                         77
# 4.96                         74
# 4.78                         71
# 4.85                         69
# 4.87                         64
# 4.71                         63
# 4.84                         62

# %%
#Realizamos grafico de dispersion del dataframe filtrado
table39.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>
